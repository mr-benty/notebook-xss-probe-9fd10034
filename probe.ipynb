# %% [markdown]
# # t
# <img src=x onerror="alert(document.domain)">
# <a href="javascript:alert(1)">js</a>
# <script>alert('mdcell')</script>

# %%
pass
# Out:
# <img src=x onerror="alert('htmlout-XSSPROBE')"><svg onload=alert('svg-XSSPROBE')><script>alert('scriptout-XSSPROBE')</script>
