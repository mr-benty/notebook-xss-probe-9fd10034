# %%
import probe
<script>alert('NB-PROBE-MARK-SOURCE')</script>
# Out:
# fallback text
# plain fallback
# <script>alert('NB-PROBE-MARK-STREAM-STDOUT')</script>

# %% [markdown]
# # Probe Markdown Cell
#
# Raw HTML: <script>alert('NB-PROBE-MARK-MD-SCRIPT')</script>
#
# <img src=x onerror="document.title='NB-PROBE-MARK-MD-IMG'">
#
# <svg onload=alert('NB-PROBE-MARK-MD-SVG')></svg>
#
# <iframe src="javascript:alert('NB-PROBE-MARK-MD-IFRAME')"></iframe>
#
# [link](javascript:alert('NB-PROBE-MARK-MD-LINK-JS'))
#
# [link2](...)
#
# $$ \href{javascript:alert('NB-PROBE-MARK-MD-LATEX-HREF')}{click} $$
#
# $$\style{color:red;font-family:'\";} #x{x:expression(alert('NB-PROBE-MARK-MD-LATEX-CSS'))}\"'}{X}$$

# %% [raw]
# <script>alert('NB-PROBE-MARK-RAW-CELL-SCRIPT')</script>
# <img src=x onerror="document.title='NB-PROBE-MARK-RAW-CELL-IMG'">
